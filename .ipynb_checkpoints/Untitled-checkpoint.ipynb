# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
import SUITPy as suit
import nibabel as nb

fig, ax = plt.subplots()
patches = []
A=nb.load('surfaces/FLAT.surf.gii')
Vertices,Faces = A.agg_data()

for i in range(Faces.shape[0]):
    polygon = Polygon(Vertices[Faces[i],0:2], True)
    patches.append(polygon)

p = PatchCollection(patches, cmap=matplotlib.cm.jet, alpha=0.4)

colors = 100*np.random.rand(len(patches))
p.set_array(np.array(colors))

ax.add_collection(p)
ax.set_xlim(-100,100)
ax.set_ylim(-100,100)
plt.show()

# %%
p.set_facecolors()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-de11f4045e1e> in <module>
# ----> 1 p.set_facecolors()
#
# ~/.local/share/virtualenvs/Python--3BEScb9/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in method(self, *args, **kwargs)
#    1874         @functools.wraps(getattr(cls, name))
#    1875         def method(self, *args, **kwargs):
# -> 1876             return getattr(self, name)(*args, **kwargs)
#    1877         return method
#    1878
#
# TypeError: set_facecolor() missing 1 required positional argument: 'c'

# %%
Vertices[Faces[0:2],0:2]
# Out:
# array([[[21.189785 ,  2.5686152],
#         [20.541264 ,  2.4435081],
#         [21.110317 ,  1.750482 ]],
#
#        [[20.31548  ,  1.6386862],
#         [21.110317 ,  1.750482 ],
#         [20.541264 ,  2.4435081]]], dtype=float32)
